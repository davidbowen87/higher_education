# %% [markdown]
# # Cleaning Institutional Characteristics (IS) Data
#
# In this notebook, we will clean the Institutional Characteristics data from IPEDS and prepare it for analysis.
#
# ## Load the Data
#
# We will start by loading the data into a Pandas DataFrame and assigning it to the `IS2021_df` variable.
#
# ## Clean the Data
#
# Next, we will clean the data by dropping any duplicate rows, converting the ZIP code column to integers, and removing any leading or trailing whitespace in string columns.
#
# Rows with missing data we not removed.
#
# Columns that we do not need are removed. Columns kept for the IS2021_df are:
# - UNITID (this the unique key for each university)
# - INSTNM (institution (entity) name )
# - CITY
# - STABBR (state abbreviation)
# - ZIP (Zipcode)
# - CONTROL (Institutional Control or Affiliation (Public, private, for-profit, or religious affiliation)
# - HLOFFER (Filter for 4-year/ Backelor's degree or higher (5))
# - INSTSIZE	Institution size category based on total students enrolled for
# - LONGITUD	(Longitude location of institution)
# - LATITUDE	(Latitude location of institution)
# - Year (added by coders to orginial data set)
#
#
# ## Save the Cleaned Data
#
# Finally, we will save the cleaned data to a new CSV file named `IS2021_cleaned.csv`.

# %%
# import dependencies 
import pandas as pd

# %%
# Load the data into a Pandas DataFrame and assign it to IS2021 variable
IS2021_df = pd.read_csv('Resources/hd2021.csv', encoding='ISO-8859-1')
IS2021_df.head()
# Out:
#    Year  UNITID                               INSTNM  \
# 0  2021  100654             Alabama A & M University
# 1  2021  100663  University of Alabama at Birmingham
# 2  2021  100690                   Amridge University
# 3  2021  100706  University of Alabama in Huntsville
# 4  2021  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1                                                UAB
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD           COUNTYNM  CNGDSTCD  \
# 0       5  ...        1  290    -2      1089     Madison County       105
# 1       5  ...        1  142    -2      1073   Jefferson County       107
# 2       5  ...        1  388    -2      1101  Montgomery County       102
# 3       5  ...        1  290    -2      1089     Madison County       105
# 4       5  ...        1  388    -2      1101  Montgomery County       107
#
#     LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 0 -86.568502  34.783368     109        1
# 1 -86.799345  33.505697      93        1
# 2 -86.174010  32.362609     127        2
# 3 -86.640449  34.724557      93        2
# 4 -86.295677  32.364317      99        1
#
# [5 rows x 75 columns]

# %%
# print number of rows and columns currently present before cleaning 
print("Number of rows:", IS2021_df.shape[0])
print("Number of columns:", IS2021_df.shape[1])
# Out:
# Number of rows: 6289
# Number of columns: 75

# %%
# review data types for all 74 columns 
IS2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6289 entries, 0 to 6288
# Data columns (total 75 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6289 non-null   int64
#  1   UNITID    6289 non-null   int64
#  2   INSTNM    6289 non-null   object
#  3   IALIAS    6288 non-null   object
#  4   ADDR      6289 non-null   object
#  5   CITY      6289 non-null   object
#  6   STABBR    6289 non-null   object
#  7   ZIP       6289 non-null   object
#  8   FIPS      6289 non-null   int64
#  9   OBEREG    6289 non-null   int64
#  10  CHFNM     6289 non-null   object
#  11  CHFTITLE  6289 non-null   object
#  12  GENTELE   6289 non-null   object
#  13  EIN       6289 non-null   int64
#  14  DUNS      6289 non-null   object
#  15  OPEID     6289 non-null   int64
#  16  OPEFLAG   6289 non-null   int64
#  17  WEBADDR   6289 non-null   object
#  18  ADMINURL  6289 non-null   object
#  19  FAIDURL   6289 non-null   object
#  20  APPLURL   6289 non-null   object
#  21  NPRICURL  6289 non-null   object
#  22  VETURL    6289 non-null   object
#  23  ATHURL    6289 non-null   object
#  24  DISAURL   6289 non-null   object
#  25  SECTOR    6289 non-null   int64
#  26  ICLEVEL   6289 non-null   int64
#  27  CONTROL   6289 non-null   int64
#  28  HLOFFER   6289 non-null   int64
#  29  UGOFFER   6289 non-null   int64
#  30  GROFFER   6289 non-null   int64
#  31  HDEGOFR1  6289 non-null   int64
#  32  DEGGRANT  6289 non-null   int64
#  33  HBCU      6289 non-null   int64
#  34  HOSPITAL  6289 non-null   int64
#  35  MEDICAL   6289 non-null   int64
#  36  TRIBAL    6289 non-null   int64
#  37  LOCALE    6289 non-null   int64
#  38  OPENPUBL  6289 non-null   int64
#  39  ACT       6289 non-null   object
#  40  NEWID     6289 non-null   int64
#  41  DEATHYR   6289 non-null   int64
#  42  CLOSEDAT  6289 non-null   object
#  43  CYACTIVE  6289 non-null   int64
#  44  POSTSEC   6289 non-null   int64
#  45  PSEFLAG   6289 non-null   int64
#  46  PSET4FLG  6289 non-null   int64
#  47  RPTMTH    6289 non-null   int64
#  48  INSTCAT   6289 non-null   int64
#  49  C21BASIC  6289 non-null   int64
#  50  C21IPUG   6289 non-null   int64
#  51  C21IPGRD  6289 non-null   int64
#  52  C21UGPRF  6289 non-null   int64
#  53  C21ENPRF  6289 non-null   int64
#  54  C21SZSET  6289 non-null   int64
#  55  C18BASIC  6289 non-null   int64
#  56  C15BASIC  6289 non-null   int64
#  57  CCBASIC   6289 non-null   int64
#  58  CARNEGIE  6289 non-null   int64
#  59  LANDGRNT  6289 non-null   int64
#  60  INSTSIZE  6289 non-null   int64
#  61  F1SYSTYP  6289 non-null   int64
#  62  F1SYSNAM  6289 non-null   object
#  63  F1SYSCOD  6289 non-null   int64
#  64  CBSA      6289 non-null   int64
#  65  CBSATYPE  6289 non-null   int64
#  66  CSA       6289 non-null   int64
#  67  NECTA     6289 non-null   int64
#  68  COUNTYCD  6289 non-null   int64
#  69  COUNTYNM  6289 non-null   object
#  70  CNGDSTCD  6289 non-null   int64
#  71  LONGITUD  6289 non-null   float64
#  72  LATITUDE  6289 non-null   float64
#  73  DFRCGID   6289 non-null   int64
#  74  DFRCUSCG  6289 non-null   int64
# dtypes: float64(2), int64(51), object(22)
# memory usage: 3.6+ MB

# %%
# Drop any duplicate rows
IS2021_df.drop_duplicates(inplace=True)

# print number of rows and columns currently present before cleaning 
print("Number of rows:", IS2021_df.shape[0])
print("Number of columns:", IS2021_df.shape[1])
# Out:
# Number of rows: 6289
# Number of columns: 75

# %%
# Convert the ZIP code column to integers and retain leading zeros
IS2021_df['ZIP'] = IS2021_df['ZIP'].apply(lambda x: int(str(x).zfill(5)[:5]))   
IS2021_df['ZIP'] = IS2021_df['ZIP'].astype(int)


 # Review data types for all 74 columns
IS2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6289 entries, 0 to 6288
# Data columns (total 75 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6289 non-null   int64
#  1   UNITID    6289 non-null   int64
#  2   INSTNM    6289 non-null   object
#  3   IALIAS    6288 non-null   object
#  4   ADDR      6289 non-null   object
#  5   CITY      6289 non-null   object
#  6   STABBR    6289 non-null   object
#  7   ZIP       6289 non-null   int32
#  8   FIPS      6289 non-null   int64
#  9   OBEREG    6289 non-null   int64
#  10  CHFNM     6289 non-null   object
#  11  CHFTITLE  6289 non-null   object
#  12  GENTELE   6289 non-null   object
#  13  EIN       6289 non-null   int64
#  14  DUNS      6289 non-null   object
#  15  OPEID     6289 non-null   int64
#  16  OPEFLAG   6289 non-null   int64
#  17  WEBADDR   6289 non-null   object
#  18  ADMINURL  6289 non-null   object
#  19  FAIDURL   6289 non-null   object
#  20  APPLURL   6289 non-null   object
#  21  NPRICURL  6289 non-null   object
#  22  VETURL    6289 non-null   object
#  23  ATHURL    6289 non-null   object
#  24  DISAURL   6289 non-null   object
#  25  SECTOR    6289 non-null   int64
#  26  ICLEVEL   6289 non-null   int64
#  27  CONTROL   6289 non-null   int64
#  28  HLOFFER   6289 non-null   int64
#  29  UGOFFER   6289 non-null   int64
#  30  GROFFER   6289 non-null   int64
#  31  HDEGOFR1  6289 non-null   int64
#  32  DEGGRANT  6289 non-null   int64
#  33  HBCU      6289 non-null   int64
#  34  HOSPITAL  6289 non-null   int64
#  35  MEDICAL   6289 non-null   int64
#  36  TRIBAL    6289 non-null   int64
#  37  LOCALE    6289 non-null   int64
#  38  OPENPUBL  6289 non-null   int64
#  39  ACT       6289 non-null   object
#  40  NEWID     6289 non-null   int64
#  41  DEATHYR   6289 non-null   int64
#  42  CLOSEDAT  6289 non-null   object
#  43  CYACTIVE  6289 non-null   int64
#  44  POSTSEC   6289 non-null   int64
#  45  PSEFLAG   6289 non-null   int64
#  46  PSET4FLG  6289 non-null   int64
#  47  RPTMTH    6289 non-null   int64
#  48  INSTCAT   6289 non-null   int64
#  49  C21BASIC  6289 non-null   int64
#  50  C21IPUG   6289 non-null   int64
#  51  C21IPGRD  6289 non-null   int64
#  52  C21UGPRF  6289 non-null   int64
#  53  C21ENPRF  6289 non-null   int64
#  54  C21SZSET  6289 non-null   int64
#  55  C18BASIC  6289 non-null   int64
#  56  C15BASIC  6289 non-null   int64
#  57  CCBASIC   6289 non-null   int64
#  58  CARNEGIE  6289 non-null   int64
#  59  LANDGRNT  6289 non-null   int64
#  60  INSTSIZE  6289 non-null   int64
#  61  F1SYSTYP  6289 non-null   int64
#  62  F1SYSNAM  6289 non-null   object
#  63  F1SYSCOD  6289 non-null   int64
#  64  CBSA      6289 non-null   int64
#  65  CBSATYPE  6289 non-null   int64
#  66  CSA       6289 non-null   int64
#  67  NECTA     6289 non-null   int64
#  68  COUNTYCD  6289 non-null   int64
#  69  COUNTYNM  6289 non-null   object
#  70  CNGDSTCD  6289 non-null   int64
#  71  LONGITUD  6289 non-null   float64
#  72  LATITUDE  6289 non-null   float64
#  73  DFRCGID   6289 non-null   int64
#  74  DFRCUSCG  6289 non-null   int64
# dtypes: float64(2), int32(1), int64(51), object(21)
# memory usage: 3.6+ MB

# %%
IS2021_df.head()
# Out:
#    Year  UNITID                               INSTNM  \
# 0  2021  100654             Alabama A & M University
# 1  2021  100663  University of Alabama at Birmingham
# 2  2021  100690                   Amridge University
# 3  2021  100706  University of Alabama in Huntsville
# 4  2021  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1                                                UAB
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR    ZIP  FIPS  OBEREG  \
# 0            4900 Meridian Street      Normal     AL  35762     1       5
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294     1       5
# 2                  1200 Taylor Rd  Montgomery     AL  36117     1       5
# 3                 301 Sparkman Dr  Huntsville     AL  35899     1       5
# 4            915 S Jackson Street  Montgomery     AL  36104     1       5
#
#    ... CBSATYPE  CSA NECTA  COUNTYCD           COUNTYNM  CNGDSTCD   LONGITUD  \
# 0  ...        1  290    -2      1089     Madison County       105 -86.568502
# 1  ...        1  142    -2      1073   Jefferson County       107 -86.799345
# 2  ...        1  388    -2      1101  Montgomery County       102 -86.174010
# 3  ...        1  290    -2      1089     Madison County       105 -86.640449
# 4  ...        1  388    -2      1101  Montgomery County       107 -86.295677
#
#     LATITUDE DFRCGID DFRCUSCG
# 0  34.783368     109        1
# 1  33.505697      93        1
# 2  32.362609     127        2
# 3  34.724557      93        2
# 4  32.364317      99        1
#
# [5 rows x 75 columns]

# %%
print(IS2021_df.iloc[400:420])
# Out:
#      Year  UNITID                                   INSTNM  \
# 400  2021  120661        Concorde Career College-San Diego
# 401  2021  120698                     Palo Alto University
# 402  2021  120768                     Pacific Oaks College
# 403  2021  120795               Pacific School of Religion
# 404  2021  120838                Pacific States University
# 405  2021  120865                    Pacific Union College
# 406  2021  120883                University of the Pacific
# 407  2021  120953                       Palo Verde College
# 408  2021  120971                          Palomar College
# 409  2021  121044                    Pasadena City College
# 410  2021  121150                    Pepperdine University
# 411  2021  121178  Peralta Community College System Office
# 412  2021  121257                           Pitzer College
# 413  2021  121275                  Platt College-San Diego
# 414  2021  121309           Point Loma Nazarene University
# 415  2021  121345                           Pomona College
# 416  2021  121363                      Porterville College
# 417  2021  121433         Professional Institute of Beauty
# 418  2021  121619                        Santa Ana College
# 419  2021  121628              Pardee RAND Graduate School
#
#                                                 IALIAS  \
# 400
# 401              Pacific Graduate School of Psychology
# 402
# 403
# 404
# 405                                                PUC
# 406  Pacific | UOP | University of Pacific | Pacifi...
# 407
# 408
# 409
# 410
# 411
# 412                           Pitzer|Pfizer|PZ|PTZ|PIT
# 413
# 414                                               PLNU
# 415
# 416
# 417
# 418                                                SAC
# 419
#
#                                 ADDR          CITY STABBR    ZIP  FIPS  \
# 400  4393 Imperial Avenue, Suite 100     San Diego     CA  92113     6
# 401              1791 Arastradero Rd     Palo Alto     CA  94304     6
# 402               45 W Eureka Street      Pasadena     CA  91103     6
# 403                  1798 Scenic Ave      Berkeley     CA  94709     6
# 404   3424 Wilshire Blvd. 12th floor   Los Angeles     CA  90010     6
# 405                   One Angwin Ave        Angwin     CA  94508     6
# 406                 3601 Pacific Ave      Stockton     CA  95211     6
# 407                One College Drive        Blythe     CA  92225     6
# 408                  1140 W. Mission    San Marcos     CA  92069     6
# 409            1570 E Colorado Blvd.      Pasadena     CA  91106     6
# 410          24255 Pacific Coast Hwy        Malibu     CA  90263     6
# 411                  333 E Eighth St       Oakland     CA  94606     6
# 412          1050 North Mills Avenue     Claremont     CA  91711     6
# 413               6250 El Cajon Blvd     San Diego     CA  92115     6
# 414                 3900 Lomaland Dr     San Diego     CA  92106     6
# 415                550 N College Ave     Claremont     CA  91711     6
# 416                100 E College Ave   Porterville     CA  93257     6
# 417             10801 E. Valley Mall      El Monte     CA  91731     6
# 418              1530 W. 17th Street     Santa Ana     CA  92706     6
# 419                     1776 Main St  Santa Monica     CA  90401     6
#
#      OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD            COUNTYNM  CNGDSTCD  \
# 400       8  ...        1   -2    -2      6073    San Diego County       651
# 401       8  ...        1  488    -2      6085  Santa Clara County       618
# 402       8  ...        1  348    -2      6037  Los Angeles County       627
# 403       8  ...        1  488    -2      6001      Alameda County       613
# 404       8  ...        1  348    -2      6037  Los Angeles County       634
# 405       8  ...        1  488    -2      6055         Napa County       605
# 406       8  ...        1  488    -2      6077  San Joaquin County       609
# 407       8  ...        1  348    -2      6065    Riverside County       636
# 408       8  ...        1   -2    -2      6073    San Diego County       650
# 409       8  ...        1  348    -2      6037  Los Angeles County       627
# 410       8  ...        1  348    -2      6037  Los Angeles County       633
# 411       8  ...        1  488    -2      6001      Alameda County       613
# 412       8  ...        1  348    -2      6037  Los Angeles County       627
# 413       8  ...        1   -2    -2      6073    San Diego County       653
# 414       8  ...        1   -2    -2      6073    San Diego County       652
# 415       8  ...        1  348    -2      6037  Los Angeles County       627
# 416       8  ...        1   -2    -2      6107       Tulare County       623
# 417       8  ...        1  348    -2      6037  Los Angeles County       632
# 418       8  ...        1  348    -2      6059       Orange County       646
# 419       8  ...        1  348    -2      6037  Los Angeles County       633
#
#        LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 400 -117.102845  32.702814     178        1
# 401 -122.187437  37.382216     155        1
# 402 -118.151323  34.153382     122        1
# 403 -122.263155  37.876690     151        2
# 404 -118.298408  34.061315     165        2
# 405 -122.440308  38.570585     140        1
# 406 -121.312301  37.981424     100        1
# 407 -114.651698  33.661538      65        2
# 408 -117.183978  33.149483      69        1
# 409 -118.118196  34.144552      60        1
# 410 -118.707077  34.037786     100        1
# 411 -122.260837  37.792667      -2       -2
# 412 -117.706675  34.104107     134        1
# 413 -117.063483  32.763730     168        2
# 414 -117.250265  32.718391     112        1
# 415 -117.714556  34.099027     132        1
# 416 -119.014368  36.049256      78        1
# 417 -118.039028  34.075561      25        2
# 418 -117.887558  33.759309     188        2
# 419 -118.490655  34.009730     173        2
#
# [20 rows x 75 columns]

# %%
# first attempt tried again to keep zeros that were part of the zip code in the front, not concered will use lat and lit for map
# First attempt 
# Remove the hyphen and last 4 digits from zip code so it can be convered to an iteger
# IS2021_df['ZIP'] = IS2021_df['ZIP'].apply(lambda x: int(str(x)[:5]))

# %%
# first attempt tried again to keep zeros that were part of the zip code in the front, not concered will use lat and lit for map
# Convert the ZIP code column to integers
# IS2021_df['ZIP'] = IS2021_df['ZIP'].astype(int)

# review data types for all 74 columns 
# IS2021_df.info()

# %%
# Remove any leading or trailing whitespace in string columns
IS2021_df = IS2021_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
# checking current df
IS2021_df.head()
# Out:
#    Year  UNITID                               INSTNM  \
# 0  2021  100654             Alabama A & M University
# 1  2021  100663  University of Alabama at Birmingham
# 2  2021  100690                   Amridge University
# 3  2021  100706  University of Alabama in Huntsville
# 4  2021  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1                                                UAB
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR    ZIP  FIPS  OBEREG  \
# 0            4900 Meridian Street      Normal     AL  35762     1       5
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294     1       5
# 2                  1200 Taylor Rd  Montgomery     AL  36117     1       5
# 3                 301 Sparkman Dr  Huntsville     AL  35899     1       5
# 4            915 S Jackson Street  Montgomery     AL  36104     1       5
#
#    ... CBSATYPE  CSA NECTA  COUNTYCD           COUNTYNM  CNGDSTCD   LONGITUD  \
# 0  ...        1  290    -2      1089     Madison County       105 -86.568502
# 1  ...        1  142    -2      1073   Jefferson County       107 -86.799345
# 2  ...        1  388    -2      1101  Montgomery County       102 -86.174010
# 3  ...        1  290    -2      1089     Madison County       105 -86.640449
# 4  ...        1  388    -2      1101  Montgomery County       107 -86.295677
#
#     LATITUDE DFRCGID DFRCUSCG
# 0  34.783368     109        1
# 1  33.505697      93        1
# 2  32.362609     127        2
# 3  34.724557      93        2
# 4  32.364317      99        1
#
# [5 rows x 75 columns]

# %%
# checking last 10 lines 
IS2021_df.tail(10)
# Out:
#       Year  UNITID                                             INSTNM IALIAS  \
# 6279  2021  497240  Shoreline Community College - CNC Machinists P...
# 6280  2021  497259       Shoreline Community College - Dental Hygiene
# 6281  2021  497268          Arizona College of Nursing-Salt Lake City
# 6282  2021  497277                           Arizona College-Glendale
# 6283  2021  497286           Universal Technical Institute-West Texas
# 6284  2021  497301                         Avalon Institute-Las Vegas
# 6285  2021  497310  Medspa Academies-National Institute of Modern ...
# 6286  2021  497329                     American Institute-Cherry Hill
# 6287  2021  497338  Glendale Career College-North-West College-Bak...
# 6288  2021  497347                      University of Maine - Machias
#
#                                                    ADDR         CITY STABBR  \
# 6279                6737 Corson Avenue South Building A      Seattle     WA
# 6280  1959 Northeast Pacific Street Magnuson HealthS...      Seattle     WA
# 6281                  434 West Ascension Way, Suite 122       Murray     UT
# 6282                   4425 West Olive Avenue Suite 300     Glendale     AZ
# 6283                               301 West Howard Lane       Austin     TX
# 6284     2650 South Decatur Boulevard Suites 1, 6, 8-10    Las Vegas     NV
# 6285               3993 Howard Hughes Parkway Suite 150    Las Vegas     NV
# 6286                            2201 Route 38 8th Floor  Cherry Hill     NJ
# 6287                                   3000 Ming Avenue  Bakersfield     CA
# 6288                                 116 O'Brien Avenue      Machias     ME
#
#         ZIP  FIPS  OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD  \
# 6279  98108    53       8  ...        1  500    -2     53033
# 6280  98195    53       8  ...        1  500    -2     53033
# 6281  84123    49       7  ...        1  482    -2     49035
# 6282  85302     4       6  ...        1  429    -2      4013
# 6283  78753    48       6  ...        1   -2    -2     48453
# 6284  89102    32       8  ...        1  332    -2     32003
# 6285  89169    32       8  ...        1  332    -2     32003
# 6286   8002    34       2  ...        1  428    -2     34007
# 6287  93304     6       8  ...        1   -2    -2      6029
# 6288   4654    23       1  ...       -2   -2    -2     23029
#
#                COUNTYNM  CNGDSTCD    LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 6279        King County      5309 -122.326138  47.542457      -2       -2
# 6280        King County      5307 -122.309103  47.650612      -2       -2
# 6281   Salt Lake County      4904 -111.903426  40.656372     202        2
# 6282    Maricopa County       408 -112.154175  33.566263     220        2
# 6283      Travis County      4817  -97.660482  30.415828     221        2
# 6284       Clark County      3201 -115.206409  36.142355      45        2
# 6285       Clark County      3201 -115.158173  36.117236      29        2
# 6286      Camden County      3401  -75.015417  39.939428      57        2
# 6287        Kern County       623 -119.035082  35.339951     221        2
# 6288  Washington County      2302  -67.458025  44.708803      -2       -2
#
# [10 rows x 75 columns]

# %%
# Select the columns to keep in the new DataFrame
keep_cols = ['Year', 'UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'CONTROL', 'HLOFFER', 'INSTSIZE', 'LONGITUD', 'LATITUDE']

# Create the new DataFrame with selected columns
IS2021_reduced_df = IS2021_df[keep_cols].copy()

# Review the first 5 rows of the new DataFrame
IS2021_reduced_df.head()
# Out:
#    Year  UNITID                               INSTNM        CITY STABBR  \
# 0  2021  100654             Alabama A & M University      Normal     AL
# 1  2021  100663  University of Alabama at Birmingham  Birmingham     AL
# 2  2021  100690                   Amridge University  Montgomery     AL
# 3  2021  100706  University of Alabama in Huntsville  Huntsville     AL
# 4  2021  100724             Alabama State University  Montgomery     AL
#
#      ZIP  CONTROL  HLOFFER  INSTSIZE   LONGITUD   LATITUDE
# 0  35762        1        9         3 -86.568502  34.783368
# 1  35294        1        9         5 -86.799345  33.505697
# 2  36117        2        9         1 -86.174010  32.362609
# 3  35899        1        9         3 -86.640449  34.724557
# 4  36104        1        9         2 -86.295677  32.364317

# %%
# print number of rows and columns currently present before cleaning 
print("Number of rows:", IS2021_df.shape[0])
print("Number of columns:", IS2021_df.shape[1])
# Out:
# Number of rows: 6289
# Number of columns: 75

# %%
# review data types for all 74 columns 
IS2021_reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6289 entries, 0 to 6288
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6289 non-null   int64
#  1   UNITID    6289 non-null   int64
#  2   INSTNM    6289 non-null   object
#  3   CITY      6289 non-null   object
#  4   STABBR    6289 non-null   object
#  5   ZIP       6289 non-null   int32
#  6   CONTROL   6289 non-null   int64
#  7   HLOFFER   6289 non-null   int64
#  8   INSTSIZE  6289 non-null   int64
#  9   LONGITUD  6289 non-null   float64
#  10  LATITUDE  6289 non-null   float64
# dtypes: float64(2), int32(1), int64(5), object(3)
# memory usage: 565.0+ KB

# %%
# Save the cleaned data to a new CSV file
IS2021_reduced_df.to_csv('Resources/IS2021_reduced.csv', index=False)

# %%
IS2021_reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6289 entries, 0 to 6288
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6289 non-null   int64
#  1   UNITID    6289 non-null   int64
#  2   INSTNM    6289 non-null   object
#  3   CITY      6289 non-null   object
#  4   STABBR    6289 non-null   object
#  5   ZIP       6289 non-null   int32
#  6   CONTROL   6289 non-null   int64
#  7   HLOFFER   6289 non-null   int64
#  8   INSTSIZE  6289 non-null   int64
#  9   LONGITUD  6289 non-null   float64
#  10  LATITUDE  6289 non-null   float64
# dtypes: float64(2), int32(1), int64(5), object(3)
# memory usage: 565.0+ KB
