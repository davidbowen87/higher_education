# %%
import pandas as pd

# %%
# Read the three CSV files
df1 = pd.read_csv("Resources/IS_HR_2019.csv")
df2 = pd.read_csv("Resources/IS_HR_2020.csv")
df3 = pd.read_csv("Resources/IS_HR_2021.csv")

# %%
df1.head()
# Out:
#    Year  UNITID  FACSTAT  ARANK  HRTOTLT  HRTOTLM  HRTOTLW  \
# 0  2019  100654        0      0      242      131      111
# 1  2019  100654       10      0      242      131      111
# 2  2019  100654       10      1       49       37       12
# 3  2019  100654       10      2       50       34       16
# 4  2019  100654       10      3       98       46       52
#
#                      INSTNM    CITY STABBR    ZIP  CONTROL  HLOFFER  INSTSIZE  \
# 0  Alabama A & M University  Normal     AL  35762        1        9         3
# 1  Alabama A & M University  Normal     AL  35762        1        9         3
# 2  Alabama A & M University  Normal     AL  35762        1        9         3
# 3  Alabama A & M University  Normal     AL  35762        1        9         3
# 4  Alabama A & M University  Normal     AL  35762        1        9         3
#
#     LONGITUD   LATITUDE
# 0 -86.568502  34.783368
# 1 -86.568502  34.783368
# 2 -86.568502  34.783368
# 3 -86.568502  34.783368
# ...

# %%
df2.head()
# Out:
#    Year  UNITID  FACSTAT  ARANK  HRTOTLT  HRTOTLM  HRTOTLW  \
# 0  2020  100654        0      0      253      137      116
# 1  2020  100654       10      0      239      129      110
# 2  2020  100654       10      1       52       40       12
# 3  2020  100654       10      2       46       31       15
# 4  2020  100654       10      3       94       43       51
#
#                      INSTNM    CITY STABBR    ZIP  CONTROL  HLOFFER  INSTSIZE  \
# 0  Alabama A & M University  Normal     AL  35762        1        9         3
# 1  Alabama A & M University  Normal     AL  35762        1        9         3
# 2  Alabama A & M University  Normal     AL  35762        1        9         3
# 3  Alabama A & M University  Normal     AL  35762        1        9         3
# 4  Alabama A & M University  Normal     AL  35762        1        9         3
#
#     LONGITUD   LATITUDE
# 0 -86.568502  34.783368
# 1 -86.568502  34.783368
# 2 -86.568502  34.783368
# 3 -86.568502  34.783368
# ...

# %%
df3.head()
# Out:
#    Year  UNITID  FACSTAT  ARANK  HRTOTLT  HRTOTLM  HRTOTLW  \
# 0  2021  100654        0      0      208      104      104
# 1  2021  100654       10      0      205      103      102
# 2  2021  100654       10      1       39       32        7
# 3  2021  100654       10      2       36       20       16
# 4  2021  100654       10      3       84       35       49
#
#                      INSTNM    CITY STABBR    ZIP  CONTROL  HLOFFER  INSTSIZE  \
# 0  Alabama A & M University  Normal     AL  35762        1        9         3
# 1  Alabama A & M University  Normal     AL  35762        1        9         3
# 2  Alabama A & M University  Normal     AL  35762        1        9         3
# 3  Alabama A & M University  Normal     AL  35762        1        9         3
# 4  Alabama A & M University  Normal     AL  35762        1        9         3
#
#     LONGITUD   LATITUDE
# 0 -86.568502  34.783368
# 1 -86.568502  34.783368
# 2 -86.568502  34.783368
# 3 -86.568502  34.783368
# ...

# %%
df1.info()
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65135 entries, 0 to 65134
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      65135 non-null  int64
#  1   UNITID    65135 non-null  int64
#  2   FACSTAT   65135 non-null  int64
#  3   ARANK     65135 non-null  int64
#  4   HRTOTLT   65135 non-null  int64
#  5   HRTOTLM   65135 non-null  int64
#  6   HRTOTLW   65135 non-null  int64
#  7   INSTNM    65135 non-null  object
#  8   CITY      65135 non-null  object
#  9   STABBR    65135 non-null  object
#  10  ZIP       65135 non-null  object
#  11  CONTROL   65135 non-null  int64
#  12  HLOFFER   65135 non-null  int64
#  13  INSTSIZE  65135 non-null  int64
#  14  LONGITUD  65135 non-null  float64
#  15  LATITUDE  65135 non-null  float64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 8.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63844 entries, 0 to 63843
# ...

# %%
# Merge the three data frames into one
merged_df = pd.concat([df1, df2, df3])

# %%
merged_df.head()
# Out:
#    Year  UNITID  FACSTAT  ARANK  HRTOTLT  HRTOTLM  HRTOTLW  \
# 0  2019  100654        0      0      242      131      111
# 1  2019  100654       10      0      242      131      111
# 2  2019  100654       10      1       49       37       12
# 3  2019  100654       10      2       50       34       16
# 4  2019  100654       10      3       98       46       52
#
#                      INSTNM    CITY STABBR    ZIP  CONTROL  HLOFFER  INSTSIZE  \
# 0  Alabama A & M University  Normal     AL  35762        1        9         3
# 1  Alabama A & M University  Normal     AL  35762        1        9         3
# 2  Alabama A & M University  Normal     AL  35762        1        9         3
# 3  Alabama A & M University  Normal     AL  35762        1        9         3
# 4  Alabama A & M University  Normal     AL  35762        1        9         3
#
#     LONGITUD   LATITUDE
# 0 -86.568502  34.783368
# 1 -86.568502  34.783368
# 2 -86.568502  34.783368
# 3 -86.568502  34.783368
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192604 entries, 0 to 63624
# Data columns (total 16 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Year      192604 non-null  int64
#  1   UNITID    192604 non-null  int64
#  2   FACSTAT   192604 non-null  int64
#  3   ARANK     192604 non-null  int64
#  4   HRTOTLT   192604 non-null  int64
#  5   HRTOTLM   192604 non-null  int64
#  6   HRTOTLW   192604 non-null  int64
#  7   INSTNM    192604 non-null  object
#  8   CITY      192604 non-null  object
#  9   STABBR    192604 non-null  object
#  10  ZIP       192604 non-null  object
#  11  CONTROL   192604 non-null  int64
#  12  HLOFFER   192604 non-null  int64
#  13  INSTSIZE  192604 non-null  int64
#  14  LONGITUD  192604 non-null  float64
#  15  LATITUDE  192604 non-null  float64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 25.0+ MB

# %%
# Write the merged data frame to a new CSV file
merged_df.to_csv("Resources/highered_merged_data.csv", index=False)
