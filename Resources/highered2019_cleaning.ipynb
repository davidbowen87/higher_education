# %% [markdown]
# # Cleaning Institutional Characteristics (IS) Data
#
# In this notebook, we will clean the Institutional Characteristics data from IPEDS and prepare it for analysis.
#
# ## Load the Data
#
# We will start by loading the data (hd2019 and s2019_is_rv.csv) into Pandas DataFrames and assigning it to the 'HR2019_df' and `IS2019_df`variable.
#
# ## Clean the Data
#
# Next, we will clean the data by dropping any duplicate rows, converting the ZIP code column to integers, and removing any leading or trailing whitespace in string columns.
#
# Rows with missing data we not removed.
#
# Columns that we do not need are removed. Columns kept for the IS2020_df are:
# - UNITID (this the unique key for each university)
# - INSTNM (institution (entity) name )
# - CITY
# - STABBR (state abbreviation)
# - ZIP (Zipcode)
# - CONTROL (Institutional Control or Affiliation (Public, private, for-profit, or religious affiliation)
# - HLOFFER (Filter for 4-year/ Backelor's degree or higher (5))
# - INSTSIZE	Institution size category based on total students enrolled for
# - LONGITUD	(Longitude location of institution)
# - LATITUDE	(Latitude location of institution)
# - Year (added by coders to orginial data set)
#
# HR2020_df
#
# - UNITID (unique id)
# - FACSTAT - Faculty and tenure status
# - ARANK - Academic rank (Professor, Associate Professor, Assistant professor, - - Instructor, Lecture, No academic rank)
# - HRTOTLT - Grand total
# - HRTOTLM - Grand total men
# - HRTOTLW - Grand total women
#
#
# ## Save the Cleaned Data
#
# Finally, we will save the cleaned data to a new CSV file named `IS2019_cleaned.csv` and 'HR2019_cleaned.csv'.

# %%
# import dependencies 
import pandas as pd

# %%
# Load the data into a Pandas DataFrame and assign it to IS2021 variable
IS2019_df = pd.read_csv('Resources/hd2019.csv', encoding='ISO-8859-1')
IS2019_df.head()
# Out:
#    Year  UNITID                               INSTNM  \
# 0  2019  100654             Alabama A & M University
# 1  2019  100663  University of Alabama at Birmingham
# 2  2019  100690                   Amridge University
# 3  2019  100706  University of Alabama in Huntsville
# 4  2019  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD           COUNTYNM  CNGDSTCD  \
# 0       5  ...        1  290    -2      1089     Madison County       105
# 1       5  ...        1  142    -2      1073   Jefferson County       107
# 2       5  ...        1  388    -2      1101  Montgomery County       102
# 3       5  ...        1  290    -2      1089     Madison County       105
# 4       5  ...        1  388    -2      1101  Montgomery County       107
#
#     LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 0 -86.568502  34.783368     112        1
# 1 -86.799345  33.505697      98        1
# 2 -86.174010  32.362609     129        2
# 3 -86.640449  34.724557     102        2
# 4 -86.295677  32.364317     120        1
#
# [5 rows x 74 columns]

# %%
# print number of rows and columns currently present before cleaning 
print("Number of rows:", IS2019_df.shape[0])
print("Number of columns:", IS2019_df.shape[1])
# Out:
# Number of rows: 6559
# Number of columns: 74

# %%
# review data types for all 74 columns 
IS2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6559 entries, 0 to 6558
# Data columns (total 74 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6559 non-null   int64
#  1   UNITID    6559 non-null   int64
#  2   INSTNM    6559 non-null   object
#  3   IALIAS    6558 non-null   object
#  4   ADDR      6559 non-null   object
#  5   CITY      6559 non-null   object
#  6   STABBR    6559 non-null   object
#  7   ZIP       6559 non-null   object
#  8   FIPS      6559 non-null   int64
#  9   OBEREG    6559 non-null   int64
#  10  CHFNM     6559 non-null   object
#  11  CHFTITLE  6559 non-null   object
#  12  GENTELE   6559 non-null   object
#  13  EIN       6559 non-null   int64
#  14  DUNS      6559 non-null   object
#  15  OPEID     6559 non-null   int64
#  16  OPEFLAG   6559 non-null   int64
#  17  WEBADDR   6559 non-null   object
#  18  ADMINURL  6559 non-null   object
#  19  FAIDURL   6559 non-null   object
#  20  APPLURL   6559 non-null   object
#  21  NPRICURL  6559 non-null   object
#  22  VETURL    6559 non-null   object
#  23  ATHURL    6559 non-null   object
#  24  DISAURL   6559 non-null   object
#  25  SECTOR    6559 non-null   int64
#  26  ICLEVEL   6559 non-null   int64
#  27  CONTROL   6559 non-null   int64
#  28  HLOFFER   6559 non-null   int64
#  29  UGOFFER   6559 non-null   int64
#  30  GROFFER   6559 non-null   int64
#  31  HDEGOFR1  6559 non-null   int64
#  32  DEGGRANT  6559 non-null   int64
#  33  HBCU      6559 non-null   int64
#  34  HOSPITAL  6559 non-null   int64
#  35  MEDICAL   6559 non-null   int64
#  36  TRIBAL    6559 non-null   int64
#  37  LOCALE    6559 non-null   int64
#  38  OPENPUBL  6559 non-null   int64
#  39  ACT       6559 non-null   object
#  40  NEWID     6559 non-null   int64
#  41  DEATHYR   6559 non-null   int64
#  42  CLOSEDAT  6559 non-null   object
#  43  CYACTIVE  6559 non-null   int64
#  44  POSTSEC   6559 non-null   int64
#  45  PSEFLAG   6559 non-null   int64
#  46  PSET4FLG  6559 non-null   int64
#  47  RPTMTH    6559 non-null   int64
#  48  INSTCAT   6559 non-null   int64
#  49  C18BASIC  6559 non-null   int64
#  50  C18IPUG   6559 non-null   int64
#  51  C18IPGRD  6559 non-null   int64
#  52  C18UGPRF  6559 non-null   int64
#  53  C18ENPRF  6559 non-null   int64
#  54  C18SZSET  6559 non-null   int64
#  55  C15BASIC  6559 non-null   int64
#  56  CCBASIC   6559 non-null   int64
#  57  CARNEGIE  6559 non-null   int64
#  58  LANDGRNT  6559 non-null   int64
#  59  INSTSIZE  6559 non-null   int64
#  60  F1SYSTYP  6559 non-null   int64
#  61  F1SYSNAM  6559 non-null   object
#  62  F1SYSCOD  6559 non-null   int64
#  63  CBSA      6559 non-null   int64
#  64  CBSATYPE  6559 non-null   int64
#  65  CSA       6559 non-null   int64
#  66  NECTA     6559 non-null   int64
#  67  COUNTYCD  6559 non-null   int64
#  68  COUNTYNM  6559 non-null   object
#  69  CNGDSTCD  6559 non-null   int64
#  70  LONGITUD  6559 non-null   float64
#  71  LATITUDE  6559 non-null   float64
#  72  DFRCGID   6559 non-null   int64
#  73  DFRCUSCG  6559 non-null   int64
# dtypes: float64(2), int64(50), object(22)
# memory usage: 3.7+ MB

# %%
# Drop any duplicate rows
IS2019_df.drop_duplicates(inplace=True)

# print number of rows and columns currently present before cleaning 
print("Number of rows:", IS2019_df.shape[0])
print("Number of columns:", IS2019_df.shape[1])
# Out:
# Number of rows: 6559
# Number of columns: 74

# %%
# Convert the ZIP code column to integers and retain leading zeros
IS2019_df['ZIP'] = IS2019_df['ZIP'].apply(lambda x: int(str(x).zfill(5)[:5]))   
IS2019_df['ZIP'] = IS2019_df['ZIP'].astype(int)


 # Review data types for all 74 columns
IS2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6440 entries, 0 to 6439
# Data columns (total 74 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6440 non-null   int64
#  1   UNITID    6440 non-null   int64
#  2   INSTNM    6440 non-null   object
#  3   IALIAS    6439 non-null   object
#  4   ADDR      6439 non-null   object
#  5   CITY      6440 non-null   object
#  6   STABBR    6440 non-null   object
#  7   ZIP       6440 non-null   int32
#  8   FIPS      6440 non-null   int64
#  9   OBEREG    6440 non-null   int64
#  10  CHFNM     6440 non-null   object
#  11  CHFTITLE  6440 non-null   object
#  12  GENTELE   6440 non-null   object
#  13  EIN       6440 non-null   int64
#  14  DUNS      6440 non-null   object
#  15  OPEID     6440 non-null   int64
#  16  OPEFLAG   6440 non-null   int64
#  17  WEBADDR   6440 non-null   object
#  18  ADMINURL  6440 non-null   object
#  19  FAIDURL   6440 non-null   object
#  20  APPLURL   6440 non-null   object
#  21  NPRICURL  6440 non-null   object
#  22  VETURL    6440 non-null   object
#  23  ATHURL    6440 non-null   object
#  24  DISAURL   6440 non-null   object
#  25  SECTOR    6440 non-null   int64
#  26  ICLEVEL   6440 non-null   int64
#  27  CONTROL   6440 non-null   int64
#  28  HLOFFER   6440 non-null   int64
#  29  UGOFFER   6440 non-null   int64
#  30  GROFFER   6440 non-null   int64
#  31  HDEGOFR1  6440 non-null   int64
#  32  DEGGRANT  6440 non-null   int64
#  33  HBCU      6440 non-null   int64
#  34  HOSPITAL  6440 non-null   int64
#  35  MEDICAL   6440 non-null   int64
#  36  TRIBAL    6440 non-null   int64
#  37  LOCALE    6440 non-null   int64
#  38  OPENPUBL  6440 non-null   int64
#  39  ACT       6440 non-null   object
#  40  NEWID     6440 non-null   int64
#  41  DEATHYR   6440 non-null   int64
#  42  CLOSEDAT  6440 non-null   object
#  43  CYACTIVE  6440 non-null   int64
#  44  POSTSEC   6440 non-null   int64
#  45  PSEFLAG   6440 non-null   int64
#  46  PSET4FLG  6440 non-null   int64
#  47  RPTMTH    6440 non-null   int64
#  48  INSTCAT   6440 non-null   int64
#  49  C18BASIC  6440 non-null   int64
#  50  C18IPUG   6440 non-null   int64
#  51  C18IPGRD  6440 non-null   int64
#  52  C18UGPRF  6440 non-null   int64
#  53  C18ENPRF  6440 non-null   int64
#  54  C18SZSET  6440 non-null   int64
#  55  C15BASIC  6440 non-null   int64
#  56  CCBASIC   6440 non-null   int64
#  57  CARNEGIE  6440 non-null   int64
#  58  LANDGRNT  6440 non-null   int64
#  59  INSTSIZE  6440 non-null   int64
#  60  F1SYSTYP  6440 non-null   int64
#  61  F1SYSNAM  6440 non-null   object
#  62  F1SYSCOD  6440 non-null   int64
#  63  CBSA      6440 non-null   int64
#  64  CBSATYPE  6440 non-null   int64
#  65  CSA       6440 non-null   int64
#  66  NECTA     6440 non-null   int64
#  67  COUNTYCD  6440 non-null   int64
#  68  COUNTYNM  6440 non-null   object
#  69  CNGDSTCD  6440 non-null   int64
#  70  LONGITUD  6440 non-null   float64
#  71  LATITUDE  6440 non-null   float64
#  72  DFRCGID   6440 non-null   int64
#  73  DFRCUSCG  6440 non-null   int64
# dtypes: float64(2), int32(1), int64(50), object(21)
# memory usage: 3.7+ MB

# %%
IS2019_df.head()
# Out:
#    Year  UNITID                               INSTNM  \
# 0  2019  100654             Alabama A & M University
# 1  2019  100663  University of Alabama at Birmingham
# 2  2019  100690                   Amridge University
# 3  2019  100706  University of Alabama in Huntsville
# 4  2019  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD           COUNTYNM  CNGDSTCD  \
# 0       5  ...        1  290    -2      1089     Madison County       105
# 1       5  ...        1  142    -2      1073   Jefferson County       107
# 2       5  ...        1  388    -2      1101  Montgomery County       102
# 3       5  ...        1  290    -2      1089     Madison County       105
# 4       5  ...        1  388    -2      1101  Montgomery County       107
#
#     LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 0 -86.568502  34.783368     112        1
# 1 -86.799345  33.505697      98        1
# 2 -86.174010  32.362609     129        2
# 3 -86.640449  34.724557     102        2
# 4 -86.295677  32.364317     120        1
#
# [5 rows x 74 columns]

# %%
print(IS2019_df.iloc[400:420])
# Out:
#      Year  UNITID                                          INSTNM  \
# 400  2019  120023  North Orange County Community College District
# 401  2019  120069                       North-West College-Pomona
# 402  2019  120078                  North-West College-West Covina
# 403  2019  120087                     North-West College-Van Nuys
# 404  2019  120166             Northwestern Polytechnic University
# 405  2019  120184                  Notre Dame de Namur University
# 406  2019  120254                              Occidental College
# 407  2019  120290                                  Ohlone College
# 408  2019  120342                            Orange Coast College
# 409  2019  120403                  Otis College of Art and Design
# 410  2019  120421                                  Oxnard College
# 411  2019  120537                   Hope International University
# 412  2019  120661               Concorde Career College-San Diego
# 413  2019  120698                            Palo Alto University
# 414  2019  120768                            Pacific Oaks College
# 415  2019  120795                      Pacific School of Religion
# 416  2019  120838                       Pacific States University
# 417  2019  120865                           Pacific Union College
# 418  2019  120883                       University of the Pacific
# 419  2019  120953                              Palo Verde College
#
#                                                 IALIAS  \
# 400
# 401
# 402
# 403                      North-West College - Pasadena
# 404                                                NPU
# 405                                               NDNU
# 406                                                Oxy
# 407
# 408
# 409     Otis Art Institute, Otis Parsons, Otis/Parsons
# 410
# 411  Hope|HIU|College of Arts and Sciences|College ...
# 412
# 413              Pacific Graduate School of Psychology
# 414
# 415
# 416
# 417                                                PUC
# 418  Pacific | UOP | University of Pacific | Pacifi...
# 419
#
#                                 ADDR         CITY STABBR         ZIP  FIPS  \
# 400            1830 W. Romneya Drive      Anaheim     CA  92801-1819     6
# 401                  170  W Holt Ave       Pomona     CA       91768     6
# 402                2121 W Garvey Ave  West Covina     CA       91790     6
# 403                     14540 Haynes     Van Nuys     CA       91411     6
# 404         47671 Westinghouse Drive      Fremont     CA       94539     6
# 405                 1500 Ralston Ave      Belmont     CA  94002-1908     6
# 406                   1600 Campus Rd  Los Angeles     CA  90041-3392     6
# 407               43600 Mission Blvd      Fremont     CA  94539-0390     6
# 408               2701 Fairview Road   Costa Mesa     CA       92626     6
# 409                9045 Lincoln Blvd  Los Angeles     CA  90045-3505     6
# 410                  4000 S Rose Ave       Oxnard     CA  93033-6699     6
# 411               2500 E Nutwood Ave    Fullerton     CA  92831-3199     6
# 412  4393 Imperial Avenue, Suite 100    San Diego     CA  92113-1964     6
# 413              1791 Arastradero Rd    Palo Alto     CA  94304-1337     6
# 414                 45 Eureka Street     Pasadena     CA       91103     6
# 415                  1798 Scenic Ave     Berkeley     CA       94709     6
# 416   3424 Wilshire Blvd. 12th floor  Los Angeles     CA  90010-2263     6
# 417                   One Angwin Ave       Angwin     CA  94508-9707     6
# 418                 3601 Pacific Ave     Stockton     CA  95211-0197     6
# 419                One College Drive       Blythe     CA       92225     6
#
#      OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD            COUNTYNM  CNGDSTCD  \
# 400       8  ...        1  348    -2      6059       Orange County       646
# 401       8  ...        1  348    -2      6037  Los Angeles County       635
# 402       8  ...        1  348    -2      6037  Los Angeles County       632
# 403       8  ...        1  348    -2      6037  Los Angeles County       629
# 404       8  ...        1  488    -2      6001      Alameda County       617
# 405       8  ...        1  488    -2      6081    San Mateo County       614
# 406       8  ...        1  348    -2      6037  Los Angeles County       634
# 407       8  ...        1  488    -2      6001      Alameda County       617
# 408       8  ...        1  348    -2      6059       Orange County       648
# 409       8  ...        1  348    -2      6037  Los Angeles County       643
# 410       8  ...        1  348    -2      6111      Ventura County       626
# 411       8  ...        1  348    -2      6059       Orange County       639
# 412       8  ...        1   -2    -2      6073    San Diego County       651
# 413       8  ...        1  488    -2      6085  Santa Clara County       618
# 414       8  ...        1  348    -2      6037  Los Angeles County       627
# 415       8  ...        1  488    -2      6001      Alameda County       613
# 416       8  ...        1  348    -2      6037  Los Angeles County       634
# 417       8  ...        1  488    -2      6055         Napa County       605
# 418       8  ...        1  488    -2      6077  San Joaquin County       609
# 419       8  ...        1  348    -2      6065    Riverside County       636
#
#        LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 400 -117.945559  33.849957      -2       -2
# 401 -117.751227  34.062043      55        2
# 402 -117.949583  34.072071     184        2
# 403 -118.450184  34.189497      56        2
# 404 -121.925953  37.477991     210        2
# 405 -122.284794  37.517111     125        1
# 406 -118.210908  34.127124     133        1
# 407 -121.916339  37.527730      88        1
# 408 -117.909086  33.669270      64        2
# 409 -118.416615  33.956607     175        1
# 410 -119.157604  34.166104      66        2
# 411 -117.885730  33.876160     125        1
# 412 -117.102845  32.702814     184        1
# 413 -122.187437  37.382216     160        1
# 414 -118.151323  34.153382     179        1
# 415 -122.263155  37.876690     155        2
# 416 -118.298408  34.061315     170        2
# 417 -122.440308  38.570585     143        1
# 418 -121.312301  37.981424     105        1
# 419 -114.651698  33.661538      71        2
#
# [20 rows x 74 columns]

# %%
# Remove any leading or trailing whitespace in string columns
IS2019_df = IS2019_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
# checking current df
IS2019_df.head()
# Out:
#    Year  UNITID                               INSTNM  \
# 0  2019  100654             Alabama A & M University
# 1  2019  100663  University of Alabama at Birmingham
# 2  2019  100690                   Amridge University
# 3  2019  100706  University of Alabama in Huntsville
# 4  2019  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD           COUNTYNM  CNGDSTCD  \
# 0       5  ...        1  290    -2      1089     Madison County       105
# 1       5  ...        1  142    -2      1073   Jefferson County       107
# 2       5  ...        1  388    -2      1101  Montgomery County       102
# 3       5  ...        1  290    -2      1089     Madison County       105
# 4       5  ...        1  388    -2      1101  Montgomery County       107
#
#     LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 0 -86.568502  34.783368     112        1
# 1 -86.799345  33.505697      98        1
# 2 -86.174010  32.362609     129        2
# 3 -86.640449  34.724557     102        2
# 4 -86.295677  32.364317     120        1
#
# [5 rows x 74 columns]

# %%
# checking last 10 lines 
IS2019_df.tail(10)
# Out:
#       Year  UNITID                                             INSTNM  IALIAS  \
# 6549  2019  494834                      Educational Technical College  EDUTEC
# 6550  2019  494843                            Fortis College-Landover
# 6551  2019  494852     Stautzenberger College-Rockford Career College
# 6552  2019  494861  CUNY Brooklyn College - Feirstein Graduate Sch...
# 6553  2019  494870    Rabbinical Seminary of America - Ma'yan HaTorah
# 6554  2019  494889                              Baker College - Flint
# 6555  2019  494898         WellSpring School of Allied Health-Wichita
# 6556  2019  494904                            Access Careers-Islandia
# 6557  2019  494913          Franciscan School of Theology - San Diego
# 6558  2019  494922  University of Montana (The) - Bitterroot Colle...
#
#                                    ADDR           CITY STABBR         ZIP  \
# 6549  Calle Albizu Campos #65, Interior          Lares     PR  00669-0000
# 6550             4351 Garden City Drive       Landover     MD  20785-2223
# 6551   1130 South Alpine Road Suite 100       Rockford     IL  61108-3900
# 6552               25 Washington Avenue       Brooklyn     NY  11205-1202
# 6553               113-25 Myrtle Avenue  Richmond Hill     NY  11418-1316
# 6554             1050 West Bristol Road          Flint     MI  48507-5508
# 6555     650 N Carriage Parkway, Ste 55        Wichita     KS  67208-4501
# 6556    1930 Veterans Highway, Suite 10       Islandia     NY  11749-1599
# 6557                   5998 Alcala Park      San Diego     CA  92110-2492
# 6558               103 South 9th Street       Hamilton     MT  59840-3213
#
#       FIPS  OBEREG  ... CBSATYPE  CSA NECTA  COUNTYCD                COUNTYNM  \
# 6549    72       9  ...        1   -2    -2     72081         Lares Municipio
# 6550    24       2  ...        1  548    -2     24033  Prince George's County
# 6551    17       3  ...        1  466    -2     17201        Winnebago County
# 6552    36       2  ...        1  408    -2     36047            Kings County
# 6553    36       2  ...        1  408    -2     36081           Queens County
# 6554    26       3  ...        1  220    -2     26049          Genesee County
# 6555    20       4  ...        1  556    -2     20173         Sedgwick County
# 6556    36       2  ...        1  408    -2     36103          Suffolk County
# 6557     6       8  ...        1   -2    -2      6073        San Diego County
# 6558    30       7  ...       -2   -2    -2     30081          Ravalli County
#
#       CNGDSTCD    LONGITUD   LATITUDE DFRCGID DFRCUSCG
# 6549      7298  -66.877248  18.294782     234        2
# 6550      2404  -76.866209  38.949983     227        2
# 6551      1716  -89.027291  42.255903     227        2
# 6552      3607  -73.967388  40.698507      -2       -2
# 6553      3605  -73.836262  40.700690      -2       -2
# 6554      2605  -83.697246  42.975177      -2       -2
# 6555      2004  -97.442623  37.673562     228        2
# 6556      3602  -73.175617  40.800874      61        2
# 6557       652 -117.191964  32.772407      -2       -2
# 6558      3000 -114.168368  46.246005      -2       -2
#
# [10 rows x 74 columns]

# %%
# Select the columns to keep in the new DataFrame
keep_cols = ['Year', 'UNITID', 'INSTNM', 'CITY', 'STABBR', 'ZIP', 'CONTROL', 'HLOFFER', 'INSTSIZE', 'LONGITUD', 'LATITUDE']

# Create the new DataFrame with selected columns
IS2019_reduced_df = IS2019_df[keep_cols].copy()

# Review the first 5 rows of the new DataFrame
IS2019_reduced_df.head()
# Out:
#    Year  UNITID                               INSTNM        CITY STABBR  \
# 0  2019  100654             Alabama A & M University      Normal     AL
# 1  2019  100663  University of Alabama at Birmingham  Birmingham     AL
# 2  2019  100690                   Amridge University  Montgomery     AL
# 3  2019  100706  University of Alabama in Huntsville  Huntsville     AL
# 4  2019  100724             Alabama State University  Montgomery     AL
#
#           ZIP  CONTROL  HLOFFER  INSTSIZE   LONGITUD   LATITUDE
# 0       35762        1        9         3 -86.568502  34.783368
# 1  35294-0110        1        9         5 -86.799345  33.505697
# 2  36117-3553        2        9         1 -86.174010  32.362609
# 3       35899        1        9         3 -86.640449  34.724557
# 4  36104-0271        1        9         2 -86.295677  32.364317

# %%
# print number of rows and columns currently present before cleaning 
print("Number of rows:", IS2019_reduced_df.shape[0])
print("Number of columns:", IS2019_reduced_df.shape[1])
# Out:
# Number of rows: 6559
# Number of columns: 11

# %%
# review data types for all 74 columns 
IS2019_reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6559 entries, 0 to 6558
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6559 non-null   int64
#  1   UNITID    6559 non-null   int64
#  2   INSTNM    6559 non-null   object
#  3   CITY      6559 non-null   object
#  4   STABBR    6559 non-null   object
#  5   ZIP       6559 non-null   object
#  6   CONTROL   6559 non-null   int64
#  7   HLOFFER   6559 non-null   int64
#  8   INSTSIZE  6559 non-null   int64
#  9   LONGITUD  6559 non-null   float64
#  10  LATITUDE  6559 non-null   float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 614.9+ KB

# %%
# Save the cleaned data to a new CSV file
IS2019_reduced_df.to_csv('Resources/IS2019_reduced.csv', index=False)

# %%
IS2019_reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6559 entries, 0 to 6558
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      6559 non-null   int64
#  1   UNITID    6559 non-null   int64
#  2   INSTNM    6559 non-null   object
#  3   CITY      6559 non-null   object
#  4   STABBR    6559 non-null   object
#  5   ZIP       6559 non-null   object
#  6   CONTROL   6559 non-null   int64
#  7   HLOFFER   6559 non-null   int64
#  8   INSTSIZE  6559 non-null   int64
#  9   LONGITUD  6559 non-null   float64
#  10  LATITUDE  6559 non-null   float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 614.9+ KB

# %% [markdown]
# # In this section we move into the human resource/staff data from s2020_is_rv.csv

# %%
# Load the data into a Pandas DataFrame and assign it to hr2021 variable
HR2019_df = pd.read_csv('Resources/s2019_is_rv.csv', encoding='ISO-8859-1')
HR2019_df.head()
# Out:
#    Year  UNITID  SISCAT  FACSTAT  ARANK XHRTOTLT  HRTOTLT XHRTOTLM  HRTOTLM  \
# 0  2019  100654       1        0      0        R      242        R      131
# 1  2019  100654     100       10      0        R      242        R      131
# 2  2019  100654     101       10      1        R       49        R       37
# 3  2019  100654     102       10      2        R       50        R       34
# 4  2019  100654     103       10      3        R       98        R       46
#
#   XHRTOTLW  ...  XHRUNKNM HRUNKNM  XHRUNKNW HRUNKNW  XHRNRALT HRNRALT  \
# 0        R  ...         Z       0         Z       0         R      18
# 1        R  ...         Z       0         Z       0         R      18
# 2        R  ...         Z       0         Z       0         R       2
# 3        R  ...         Z       0         Z       0         R       4
# 4        R  ...         Z       0         Z       0         R       8
#
#    XHRNRALM HRNRALM  XHRNRALW HRNRALW
# 0         R      13         R        5
# 1         R      13         R        5
# 2         R       2         Z        0
# 3         R       2         R        2
# 4         R       5         R        3
#
# [5 rows x 65 columns]

# %%
# print number of rows and columns currently present before cleaning 
print("Number of rows:", HR2019_df.shape[0])
print("Number of columns:", HR2019_df.shape[1])
# Out:
# Number of rows: 65135
# Number of columns: 65

# %%
# review data types for all 65 columns 
HR2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65135 entries, 0 to 65134
# Data columns (total 65 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      65135 non-null  int64
#  1   UNITID    65135 non-null  int64
#  2   SISCAT    65135 non-null  int64
#  3   FACSTAT   65135 non-null  int64
#  4   ARANK     65135 non-null  int64
#  5   XHRTOTLT  65135 non-null  object
#  6   HRTOTLT   65135 non-null  int64
#  7   XHRTOTLM  65135 non-null  object
#  8   HRTOTLM   65135 non-null  int64
#  9   XHRTOTLW  65135 non-null  object
#  10  HRTOTLW   65135 non-null  int64
#  11  XHRAIANT  65135 non-null  object
#  12  HRAIANT   65135 non-null  int64
#  13  XHRAIANM  65135 non-null  object
#  14  HRAIANM   65135 non-null  int64
#  15  XHRAIANW  65135 non-null  object
#  16  HRAIANW   65135 non-null  int64
#  17  XHRASIAT  65135 non-null  object
#  18  HRASIAT   65135 non-null  int64
#  19  XHRASIAM  65135 non-null  object
#  20  HRASIAM   65135 non-null  int64
#  21  XHRASIAW  65135 non-null  object
#  22  HRASIAW   65135 non-null  int64
#  23  XHRBKAAT  65135 non-null  object
#  24  HRBKAAT   65135 non-null  int64
#  25  XHRBKAAM  65135 non-null  object
#  26  HRBKAAM   65135 non-null  int64
#  27  XHRBKAAW  65135 non-null  object
#  28  HRBKAAW   65135 non-null  int64
#  29  XHRHISPT  65135 non-null  object
#  30  HRHISPT   65135 non-null  int64
#  31  XHRHISPM  65135 non-null  object
#  32  HRHISPM   65135 non-null  int64
#  33  XHRHISPW  65135 non-null  object
#  34  HRHISPW   65135 non-null  int64
#  35  XHRNHPIT  65135 non-null  object
#  36  HRNHPIT   65135 non-null  int64
#  37  XHRNHPIM  65135 non-null  object
#  38  HRNHPIM   65135 non-null  int64
#  39  XHRNHPIW  65135 non-null  object
#  40  HRNHPIW   65135 non-null  int64
#  41  XHRWHITT  65135 non-null  object
#  42  HRWHITT   65135 non-null  int64
#  43  XHRWHITM  65135 non-null  object
#  44  HRWHITM   65135 non-null  int64
#  45  XHRWHITW  65135 non-null  object
#  46  HRWHITW   65135 non-null  int64
#  47  XHR2MORT  65135 non-null  object
#  48  HR2MORT   65135 non-null  int64
#  49  XHR2MORM  65135 non-null  object
#  50  HR2MORM   65135 non-null  int64
#  51  XHR2MORW  65135 non-null  object
#  52  HR2MORW   65135 non-null  int64
#  53  XHRUNKNT  65135 non-null  object
#  54  HRUNKNT   65135 non-null  int64
#  55  XHRUNKNM  65135 non-null  object
#  56  HRUNKNM   65135 non-null  int64
#  57  XHRUNKNW  65135 non-null  object
#  58  HRUNKNW   65135 non-null  int64
#  59  XHRNRALT  65135 non-null  object
#  60  HRNRALT   65135 non-null  int64
#  61  XHRNRALM  65135 non-null  object
#  62  HRNRALM   65135 non-null  int64
#  63  XHRNRALW  65135 non-null  object
#  64  HRNRALW   65135 non-null  int64
# dtypes: int64(35), object(30)
# memory usage: 32.3+ MB

# %%
# Select the columns to keep in the new DataFrame
keep_cols = ['Year','UNITID','FACSTAT','ARANK','HRTOTLT','HRTOTLM','HRTOTLW']

# Create the new DataFrame with selected columns
HR2019_reduced_df = HR2019_df[keep_cols].copy()

# Review the first 5 rows of the new DataFrame
HR2019_reduced_df.head()
# Out:
#    Year  UNITID  FACSTAT  ARANK  HRTOTLT  HRTOTLM  HRTOTLW
# 0  2019  100654        0      0      242      131      111
# 1  2019  100654       10      0      242      131      111
# 2  2019  100654       10      1       49       37       12
# 3  2019  100654       10      2       50       34       16
# 4  2019  100654       10      3       98       46       52

# %%
# checking last 10 lines 
HR2019_reduced_df.tail(10)
# Out:
#        Year  UNITID  FACSTAT  ARANK  HRTOTLT  HRTOTLM  HRTOTLW
# 65125  2019  494843       45      4       20        5       15
# 65126  2019  494852        0      0       25        8       17
# 65127  2019  494852       10      0       25        8       17
# 65128  2019  494852       10      6       25        8       17
# 65129  2019  494852       40      0       25        8       17
# 65130  2019  494852       40      6       25        8       17
# 65131  2019  494852       41      0       25        8       17
# 65132  2019  494852       41      6       25        8       17
# 65133  2019  494852       45      0       25        8       17
# 65134  2019  494852       45      6       25        8       17

# %%
# Save the cleaned data to a new CSV file
HR2019_reduced_df.to_csv('Resources/HR2019_reduced.csv', index=False)

# %%
HR2019_reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65135 entries, 0 to 65134
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     65135 non-null  int64
#  1   UNITID   65135 non-null  int64
#  2   FACSTAT  65135 non-null  int64
#  3   ARANK    65135 non-null  int64
#  4   HRTOTLT  65135 non-null  int64
#  5   HRTOTLM  65135 non-null  int64
#  6   HRTOTLW  65135 non-null  int64
# dtypes: int64(7)
# memory usage: 3.5 MB
